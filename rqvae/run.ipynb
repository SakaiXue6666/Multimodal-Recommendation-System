# %% [markdown]
# ## Long-CLIP

# %%
# !python main.py --data_path <your_path>/TIGER/data/Beauty/item_longclip_emb.parquet
# Out:
# ...
# Namespace(lr=0.001, epochs=3000, batch_size=1024, num_workers=4, eval_step=50, learner='AdamW', lr_scheduler_type='linear', warmup_epochs=50, data_path='/root/autodl-tmp/TIGER/data/Beauty/item_mul_emb.parquet', weight_decay=0.0001, dropout_prob=0.0, bn=False, loss_type='mse', kmeans_init=True, kmeans_iters=100, sk_epsilons=[0.0, 0.0, 0.003], sk_iters=50, device='cuda:0', num_emb_list=[256, 256, 256], e_dim=32, quant_loss_weight=1.0, beta=0.25, layers=[512, 256, 128, 64], save_limit=5, ckpt_dir='./ckpt/Beauty')
# ...
# RQVAE(
#   (encoder): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Linear(in_features=1024, out_features=512, bias=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): Linear(in_features=512, out_features=256, bias=True)
#       (5): ReLU()
#       (6): Dropout(p=0.0, inplace=False)
#       (7): Linear(in_features=256, out_features=128, bias=True)
#       (8): ReLU()
# ...

# %%
# ckpt_path: your ckpt path
# output_file = f"../data/{dataset}/{dataset}_longclip_rqvae.npy"
# !python generate_code.py
# Out:
# RQVAE(
#   (encoder): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Linear(in_features=1024, out_features=512, bias=True)
#       (2): ReLU()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): Linear(in_features=512, out_features=256, bias=True)
#       (5): ReLU()
#       (6): Dropout(p=0.0, inplace=False)
#       (7): Linear(in_features=256, out_features=128, bias=True)
#       (8): ReLU()
#       (9): Dropout(p=0.0, inplace=False)
#       (10): Linear(in_features=128, out_features=64, bias=True)
#       (11): ReLU()
#       (12): Dropout(p=0.0, inplace=False)
#       (13): Linear(in_features=64, out_features=32, bias=True)
#     )
#   )
#   (rq): ResidualVectorQuantizer(
#     (vq_layers): ModuleList(
#       (0-2): 3 x VectorQuantizer(
#         (embedding): Embedding(256, 32)
#       )
#     )
#   )
#   (decoder): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
# ...

# %% [markdown]
# ## gme Qwen2-VL

# %%
# !python main.py --data_path <your_path>/TIGER/data/Beauty/item_gmeqwen2vl_emb.parquet

# %%
# ckpt_path: your ckpt path
# output_file = f"../data/{dataset}/{dataset}_gmeqwen2vl_rqvae.npy"
# !python generate_code.py
