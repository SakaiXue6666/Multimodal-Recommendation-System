# %% [markdown]
# ## Long-CLIP

# %%
# !python main1.py --code_path <your_path>/TIGER/data/Beauty/Beauty_longclip_rqvae.npy
# Out:
# #Embedding parameters: 131200
# #Non-embedding parameters: 4459648
# #Total trainable parameters: 4590848
#
# ...
# Evaluating: 100%|█████████████████████████████| 233/233 [00:06<00:00, 36.04it/s]
#
# 📊 Validation Results (Epoch 10)
#   Train Loss: 2.8838
#   Recall@5: 0.0224 | NDCG@5: 0.0144
# ✅ Saved best model (Epoch 10) → ./runs/tiger_20251110_065806/tiger_epoch10.pth
# ...
# Evaluating: 100%|█████████████████████████████| 233/233 [00:06<00:00, 35.87it/s]
#
# 📊 Validation Results (Epoch 20)
#   Train Loss: 2.4959
#   Recall@5: 0.0290 | NDCG@5: 0.0192
# ✅ Saved best model (Epoch 20) → ./runs/tiger_20251110_065806/tiger_epoch20.pth
# ...
# Evaluating: 100%|█████████████████████████████| 233/233 [00:06<00:00, 36.17it/s]
#
# 📊 Validation Results (Epoch 30)
#   Train Loss: 2.3318
#   Recall@5: 0.0340 | NDCG@5: 0.0223
# ✅ Saved best model (Epoch 30) → ./runs/tiger_20251110_065806/tiger_epoch30.pth
# ...
# Evaluating: 100%|█████████████████████████████| 233/233 [00:06<00:00, 36.27it/s]
#
# ...

# %%
# Validation Results (Epoch 160)
#   Train Loss: 1.8298
#   Recall@5: 0.0470 | NDCG@5: 0.0317
#
# Final Test Results
#   Recall@5: 0.0327 | NDCG@5: 0.0224
#   Recall@10: 0.0493 | NDCG@10: 0.0278

# %% [markdown]
# ## gme Qwen2-VL

# %%
# !python main1.py --code_path <your_path>/TIGER/data/Beauty/Beauty_gmeqwen2vl_rqvae.npy

# %%
# Validation Results (Epoch 170)
#   Train Loss: 1.7371
#   Recall@5: 0.0487 | NDCG@5: 0.0333
#
# Final Test Results
#   Recall@5: 0.0352 | NDCG@5: 0.0239
#   Recall@10: 0.0525 | NDCG@10: 0.0294
